# %% [markdown]
# ## Motif Detection
# ### Stellina Ao, 10.13.2024 -
# The purpose of this code is to detect hippocampal motifs in data collected by the Allen Institute.

# %% [markdown]
# #### Read in Data

# %%
from pynwb import NWBHDF5IO
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ks_2samp

import warnings
warnings.filterwarnings("ignore")

# %%
io = NWBHDF5IO('..\..\..\Data\sub-692072_ses-1298465622.nwb', mode="r", load_namespaces=True)
nwb = io.read()
units_raw = nwb.units
col_names = list(units_raw[0])
electrodes = nwb.electrodes
#where(nwb.electrodes['location'][:] == 'CA1')

# %%
trials_raw = nwb.behavior
type(trials_raw)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 trials_raw = nwb.behavior
#       2 type(trials_raw)
#
# AttributeError: 'NWBFile' object has no attribute 'behavior'

# %% [markdown]
# Isolate CA1

# %%
units = []

for i in range(len(units_raw)):
    peak_id = units_raw.peak_channel_id[i] # unit id --> electrode id
    location_id = np.where(electrodes.id[:]==peak_id)[0] # electrode id --> location index
    location_name = str(electrodes['location'][location_id])[2:-2] # location index --> location name

    if location_name == "CA1":
        units_i = units_raw[i].values.tolist()[0]
        units.append(units_i)

# %%
units = pd.DataFrame(units, columns=col_names)
units
# Out:
#      recovery_slope  presence_ratio  velocity_above       snr  nn_hit_rate  \
# 0         -1.000000            0.99       -0.103015  0.416924     0.270882
# 1         -0.532755            0.99        0.011446  0.703193     0.513333
# 2         -0.038140            0.99        0.892797  1.114907     0.994000
# 3         -0.043289            0.99        0.343384  1.156439     0.946667
# 4         -0.074747            0.99       -0.091569  0.969209     0.923333
# ..              ...             ...             ...       ...          ...
# 157       -0.028849            0.17       -0.022892  1.238933     0.000000
# 158       -0.131547            0.55        0.902608  4.151433     0.333333
# 159       -0.081595            0.82        0.882986  3.032849     0.611111
# 160       -0.111812            0.76        0.274707  3.683995     0.400000
# 161       -0.087038            0.75        0.824121  4.149158     0.000000
#
#       amplitude  amplitude_cutoff  cluster_id  waveform_duration  max_drift  \
# 0     67.121145          0.500000         171           1.634506      31.44
# 1     59.689110          0.500000         172           2.046566      18.74
# 2     93.104505          0.020325         173           0.494472      23.03
# 3     72.605130          0.452410         174           0.302178      18.61
# 4     59.180745          0.377369         175           0.302178      26.51
# ..          ...               ...         ...                ...        ...
# 157   94.625289          0.000681         608           0.727973       6.42
# 158  217.681379          0.004751         609           0.631826      17.04
# 159  172.240925          0.223263         614           0.631826      24.88
# 160  336.955674          0.027993         621           0.686767      24.14
# 161  158.487967          0.000701         623           0.673032       4.13
#
#      ...  quality  nn_miss_rate  spread  PT_ratio  firing_rate   l_ratio  \
# 0    ...    noise      0.022598   140.0  4.849517     2.255217  0.231291
# 1    ...    noise      0.033796   170.0  0.299286     5.813922  0.236176
# 2    ...     good      0.000368   120.0  0.381165     3.407846  0.000540
# 3    ...     good      0.044405   100.0  0.477054    12.240420  0.030185
# 4    ...    noise      0.048877   150.0  0.625579    17.362320  0.022455
# ..   ...      ...           ...     ...       ...          ...       ...
# 157  ...     good      0.000033   120.0  0.223661     0.046950  0.001384
# 158  ...     good      0.000267    70.0  0.431843     0.044356  0.011598
# 159  ...     good      0.000467    70.0  0.376840     0.098225  0.005979
# 160  ...     good      0.000300    60.0  0.277311     0.077962  0.000147
# 161  ...     good      0.000067    70.0  0.534677     0.045591  0.000452
#
#      silhouette_score                                        spike_times  \
# 0            0.096603  [22.78182278016842, 22.807422693593516, 23.131...
# 1           -0.001593  [21.57582685865791, 22.122425010148493, 22.285...
# 2            0.122963  [31.857492087674977, 32.26179072040027, 37.170...
# 3            0.071006  [20.524197081771923, 20.6163634367464, 21.1379...
# 4            0.060853  [20.71629643212198, 20.788929519821576, 20.857...
# ..                ...                                                ...
# 157         -1.000000  [3615.9006047480316, 3630.016157011443, 3633.3...
# 158          0.060925  [2421.2780447745954, 2427.3413576027533, 2457....
# 159         -1.000000  [587.0735144339675, 647.3613772165161, 743.605...
# 160         -1.000000  [36.3437769157617, 36.403476713866326, 36.5770...
# 161         -1.000000  [119.04573056402899, 176.45040309707582, 258.3...
#
#                                       spike_amplitudes  \
# 0    [3.922582485302846e-05, 3.670163308088668e-05,...
# 1    [6.217149405793323e-05, 5.594412400168287e-05,...
# 2    [0.0001111246902649, 8.990657825610332e-05, 0....
# 3    [8.397554213019525e-05, 6.347096966217724e-05,...
# 4    [8.578274397045404e-05, 6.511100066774274e-05,...
# ..                                                 ...
# 157  [0.0002137390130016982, 0.0004633663177824609,...
# 158  [0.00010851743409720796, 0.0001047824361180276...
# 159  [0.00027037865676346137, 0.0002511933876652157...
# 160  [0.00032542453922756976, 0.0003056701614838182...
# 161  [0.00010275151551352607, 9.150815357965571e-05...
#
#                                          waveform_mean
# 0    [[0.0, -0.6314099999999974, -1.365974999999999...
# 1    [[0.0, -0.5879249999999985, -1.37358, -1.10701...
# 2    [[0.0, -0.4369950000000018, -0.979875000000006...
# 3    [[0.0, 0.9455549999999984, 1.7785949999999986,...
# 4    [[0.0, -0.9594000000000021, -0.980850000000002...
# ..                                                 ...
# 157  [[0.0, -0.5983421052631572, -0.554210526315789...
# 158  [[0.0, 0.2743036211699168, -0.3117827298050144...
# 159  [[0.0, 0.05641509433962488, -0.431943396226415...
# 160  [[0.0, -1.0179556259904938, -1.368708399366088...
# 161  [[0.0, -0.8772357723577241, -1.858048780487804...
#
# [162 rows x 29 columns]

# %%
unitSpikeTimes_raw = units["spike_times"]
print(np.shape(unitSpikeTimes_raw))
unitSpikeTimes_raw[0]
# Out:
# (162,)
# array([  22.78182278,   22.80742269,   23.1314216 , ..., 8113.99835955,
#        8114.12842578, 8114.162459  ])

# %% [markdown]
# #### Convert Spike Times to Spike Trains

# %%
unitSpikeTimes = [np.round(unitSpikeTimes_raw[i], 3) for i in range(len(unitSpikeTimes_raw))] # seconds
unitSpikeTimes[0]
# Out:
# array([  22.782,   22.807,   23.131, ..., 8113.998, 8114.128, 8114.162])

# %%
unitSpikeTimes_whole = [np.unique([int(unitSpikeTimes[i][j] * 1e3) for j in range(len(unitSpikeTimes[i]))]) for i in range(len(unitSpikeTimes))] # ms
unitSpikeTimes_whole[0]
# Out:
# array([  22782,   22807,   23131, ..., 8113998, 8114128, 8114162])

# %% [markdown]
# NOTE: now, 1 s = 1000 indices; 1 ms = 1e-3 s = 1 index

# %%
spikeTrains = []
for i in range(3):
    print(i)
    spikeTimes = unitSpikeTimes_whole[i]
    length = int(spikeTimes[len(spikeTimes)-1])
    
    spikeTrains_i = np.zeros(length)
    k = 0

    for j in range(length):
        if spikeTimes[k] == j:
            spikeTrains_i[j] = 1
            k+=1

    spikeTrains.append(spikeTrains_i)
# Out:
# 0
# 1
# 2

# %%
plt.figure(figsize=(20, 5), dpi = 200)
plt.scatter(range(len(spikeTrains[0])), spikeTrains[0], s=0.5)
plt.figure(figsize=(20, 5), dpi = 200)
plt.scatter(range(len(spikeTrains[0][2000000:3000000])), spikeTrains[0][2000000:3000000], s=0.5)

# %% [markdown]
# #### Motif Detection

# %%
def peakFR(spikeTrain, windowSize = 1000): # NOTE: 1 index = 1 ms np.convolve   window = 1000 # 1000 indices = 1 s
    kernel=list(np.zeros(0)) + list(np.ones(windowSize)) + list(np.zeros(0))
    
    cST = list(np.convolve(spikeTrain, kernel))

    peakFR = max(cST)
    indexE = cST.index(max(cST)) + 1
    indexS = indexE - 1000 if indexE - 1000 >= 0 else 0
    
    return peakFR, (indexS, indexE)

def minFR(spikeTrain, windowSize = 1000):
    kernel=list(np.zeros(0)) + list(np.ones(windowSize)) + list(np.zeros(0))

    print(np.shape(spikeTrain))
    
    cST = list(np.convolve(spikeTrain, kernel, "same"))
    
    minFR = min(cST)
    indexE = cST.index(min(cST)) + 1
    indexS = indexE - 1000 if indexE - 1000 >= 0 else 0
    
    return minFR, (indexS, indexE)

# %%
def isMotif(spikeTrain):
    # conditions to be a motif:
    #     neuron achieved a peak firing rate of at least 5 Hz (5 spike/1000 indices) and 
    #     maintained a firing rate above 10% of that peak for at least 300 ms
    
    pfr, pfrIndices = peakFR(spikeTrain[0:-300])
    print(f"pfrIndices: {pfrIndices}; np.shape(spikeTrain): {np.shape(spikeTrain)}")
    mfr, mfrIndices = minFR(spikeTrain[pfrIndices[1]:pfrIndices[1]+300])

    print(f"pfr: {pfr}; mfr: {mfr}; mfrI: {mfrIndices}")

    if pfr >= 5 and mfr > 0.1*pfr:
        return True
    
    return False

# %%
def findMotifs(spikeTrain): # 
    motifIndices = []
    binLen = 2 * 1000 # 10 seconds

    for i in range(len(spikeTrain)//binLen):
        start = i * binLen
        end = (i+1)*binLen if i!=len(spikeTrain)//binLen else len(spikeTrain)+1
        
        stBin = spikeTrain[start:end]

        if isMotif(stBin):
            motifIndices.append((start, end))

    return motifIndices

# %%
findMotifs(spikeTrains[0])
# Out:
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (472, 1472); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 714); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 195); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 491); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (17, 1017); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 10.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (455, 1455); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (328, 1328); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 725); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (272, 1272); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 401); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 269); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (539, 1539); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (123, 1123); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 852); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 487); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 778); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (662, 1662); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (125, 1125); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (241, 1241); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 720); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (507, 1507); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (641, 1641); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 924); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 999)
# pfrIndices: (436, 1436); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 1.0; mfrI: (0, 1)
# pfrIndices: (1, 1001); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (132, 1132); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (21, 1021); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 298); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (582, 1582); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (688, 1688); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 1.0; mfrI: (0, 1)
# pfrIndices: (0, 997); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 960)
# pfrIndices: (0, 947); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (536, 1536); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 487); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 500); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 950); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 12.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (304, 1304); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (211, 1211); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (472, 1472); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (263, 1263); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (90, 1090); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 634); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (314, 1314); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (302, 1302); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 241); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (209, 1209); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (582, 1582); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (430, 1430); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (455, 1455); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 199); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (252, 1252); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (212, 1212); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 776); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (486, 1486); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (299, 1299); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 678); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (118, 1118); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 831); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (325, 1325); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (37, 1037); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 171); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (86, 1086); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 315); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 671); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 351); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (544, 1544); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 784); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 915); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (427, 1427); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 449); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (442, 1442); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (78, 1078); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (155, 1155); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 966); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (19, 1019); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 951); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 10.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (155, 1155); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 795); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (91, 1091); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 826); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (275, 1275); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (91, 1091); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (635, 1635); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 974)
# pfrIndices: (0, 444); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (198, 1198); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (652, 1652); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 836); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (5, 1005); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (486, 1486); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 938); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 753); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (156, 1156); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 479); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (640, 1640); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (497, 1497); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 284); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (241, 1241); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (272, 1272); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 200); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (533, 1533); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 280); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 383); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 228); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (44, 1044); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 443); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (510, 1510); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 593); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 300); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (346, 1346); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 928); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (630, 1630); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 176); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 648); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (241, 1241); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 400); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (236, 1236); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 362); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (69, 1069); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (627, 1627); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (425, 1425); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (23, 1023); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (346, 1346); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (495, 1495); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (450, 1450); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 781); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (320, 1320); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (21, 1021); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 13.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 670); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (336, 1336); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 11.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 581); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (405, 1405); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (208, 1208); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 239); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 948); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (5, 1005); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 632); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (290, 1290); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (142, 1142); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 668); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 623); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 444); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 277); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 664); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (111, 1111); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (162, 1162); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 472); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 875); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 610); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (155, 1155); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 262); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (517, 1517); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 254); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (562, 1562); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 458); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 832); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 765); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 84); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 349); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (553, 1553); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 595); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 38); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (638, 1638); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 1.0; mfrI: (0, 997)
# pfrIndices: (0, 817); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 344); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (139, 1139); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 931); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (635, 1635); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (557, 1557); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (441, 1441); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 10.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (42, 1042); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (51, 1051); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 913)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 790); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 12.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (166, 1166); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 921); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (76, 1076); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 514); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (697, 1697); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (441, 1441); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 888); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 182); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 335); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (651, 1651); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (688, 1688); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (426, 1426); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (374, 1374); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 532); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 692); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 432); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (375, 1375); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (580, 1580); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 892); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (368, 1368); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (414, 1414); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 944); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 523); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (174, 1174); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (694, 1694); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (251, 1251); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (690, 1690); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (143, 1143); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (620, 1620); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 992); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 154); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (262, 1262); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (396, 1396); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (641, 1641); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 914)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (354, 1354); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 573); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 156); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (648, 1648); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (49, 1049); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (256, 1256); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (532, 1532); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (297, 1297); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 10.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (694, 1694); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (375, 1375); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (487, 1487); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (632, 1632); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 926); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 685); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 346); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 311); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 76); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (422, 1422); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (521, 1521); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (48, 1048); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 11.0; mfr: 0.0; mfrI: (0, 988)
# pfrIndices: (470, 1470); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (52, 1052); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 13.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (67, 1067); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (516, 1516); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 533); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (630, 1630); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (656, 1656); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 902)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (533, 1533); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 230); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (686, 1686); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 12.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (692, 1692); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 864)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 926); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (466, 1466); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 762); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (398, 1398); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 385); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 990); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (519, 1519); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 714); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (564, 1564); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (256, 1256); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (380, 1380); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (169, 1169); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (510, 1510); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (321, 1321); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (317, 1317); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (282, 1282); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (558, 1558); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (260, 1260); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 911); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (124, 1124); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 317); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1000); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (91, 1091); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (287, 1287); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 391); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# ...
# pfrIndices: (585, 1585); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (482, 1482); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (135, 1135); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (29, 1029); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (34, 1034); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 637); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 451); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (172, 1172); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 393); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (411, 1411); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (583, 1583); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (685, 1685); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 34); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (686, 1686); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 1.0; mfrI: (0, 916)
# pfrIndices: (0, 672); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (34, 1034); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (436, 1436); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (435, 1435); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 10.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 628); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (531, 1531); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (89, 1089); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (9, 1009); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 994); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (352, 1352); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 731); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (658, 1658); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (205, 1205); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (689, 1689); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 1.0; mfrI: (0, 1)
# pfrIndices: (0, 929); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 839); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (467, 1467); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 995)
# pfrIndices: (323, 1323); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 743); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (612, 1612); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (477, 1477); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (636, 1636); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 1.0; mfrI: (0, 975)
# pfrIndices: (0, 571); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (585, 1585); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (454, 1454); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (311, 1311); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 834); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (495, 1495); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 320); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 351); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (647, 1647); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 18.0; mfr: 1.0; mfrI: (0, 974)
# pfrIndices: (111, 1111); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 13.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 781); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 12.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (6, 1006); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 17.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (73, 1073); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 19.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (124, 1124); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (103, 1103); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (689, 1689); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 26.0; mfr: 1.0; mfrI: (0, 920)
# pfrIndices: (0, 978); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 15.0; mfr: 1.0; mfrI: (0, 999)
# pfrIndices: (669, 1669); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 11.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (428, 1428); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 975); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 11.0; mfr: 1.0; mfrI: (0, 1)
# pfrIndices: (199, 1199); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 1.0; mfrI: (0, 1)
# pfrIndices: (679, 1679); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 17.0; mfr: 3.0; mfrI: (0, 1)
# pfrIndices: (0, 786); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 691); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (254, 1254); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 24.0; mfr: 0.0; mfrI: (0, 954)
# pfrIndices: (4, 1004); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 11.0; mfr: 0.0; mfrI: (0, 858)
# pfrIndices: (0, 990); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (321, 1321); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (545, 1545); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 637); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (565, 1565); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 256); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 737); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 832); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (478, 1478); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (207, 1207); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 874); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 828); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 856); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 952); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (223, 1223); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (696, 1696); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 1.0; mfrI: (0, 993)
# pfrIndices: (0, 886); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (328, 1328); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (583, 1583); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 822); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (603, 1603); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 273); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 61); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (353, 1353); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 983); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 975); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (196, 1196); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 189); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (457, 1457); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 997); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 990); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 791); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (428, 1428); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 10.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (499, 1499); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 557); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 429); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (534, 1534); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (578, 1578); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 1.0; mfrI: (0, 1)
# pfrIndices: (439, 1439); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 708); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 895); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 906); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (366, 1366); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (610, 1610); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (40, 1040); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 600); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 372); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 1.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (685, 1685); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (313, 1313); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (626, 1626); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 15.0; mfr: 1.0; mfrI: (0, 1)
# pfrIndices: (502, 1502); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 18.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (220, 1220); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 20.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 545); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (85, 1085); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 13.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (168, 1168); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 11.0; mfr: 0.0; mfrI: (0, 974)
# pfrIndices: (0, 770); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (197, 1197); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 13.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 711); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 11.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 956); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 10.0; mfr: 0.0; mfrI: (0, 953)
# pfrIndices: (664, 1664); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 13.0; mfr: 1.0; mfrI: (0, 990)
# pfrIndices: (366, 1366); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 10.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (362, 1362); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 854); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 9.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (227, 1227); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (151, 1151); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 980)
# pfrIndices: (683, 1683); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 890)
# pfrIndices: (168, 1168); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 901)
# pfrIndices: (214, 1214); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 160); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 895); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 5.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (543, 1543); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (141, 1141); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 1); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 0.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 575); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (39, 1039); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 681); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 961); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (281, 1281); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 7.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 997); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 2.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 953); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 4.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (660, 1660); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 736); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 3.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (624, 1624); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 14.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 969); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 12.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 719); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (63, 1063); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 859); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 954); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 15.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (313, 1313); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 13.0; mfr: 0.0; mfrI: (0, 968)
# pfrIndices: (0, 871); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 13.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (612, 1612); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 6.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (328, 1328); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 8.0; mfr: 0.0; mfrI: (0, 1)
# pfrIndices: (0, 983); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 14.0; mfr: 1.0; mfrI: (0, 1)
# pfrIndices: (594, 1594); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 10.0; mfr: 1.0; mfrI: (0, 1)
# pfrIndices: (659, 1659); np.shape(spikeTrain): (2000,)
# (300,)
# pfr: 14.0; mfr: 0.0; mfrI: (0, 1)
# [(126000, 128000),
#  (2894000, 2896000),
#  (4422000, 4424000),
#  (4718000, 4720000),
#  (4994000, 4996000),
#  (5342000, 5344000),
#  (5436000, 5438000),
#  (5522000, 5524000),
#  (5526000, 5528000),
#  (5530000, 5532000),
#  (5678000, 5680000),
#  (5904000, 5906000),
#  (6072000, 6074000),
#  (6196000, 6198000),
#  (6360000, 6362000),
#  (6440000, 6442000),
#  (6722000, 6724000),
#  (6748000, 6750000),
#  (6800000, 6802000),
#  (6906000, 6908000),
#  (6912000, 6914000),
#  (6928000, 6930000),
#  (7014000, 7016000),
#  (7032000, 7034000),
#  (7040000, 7042000),
#  (7086000, 7088000),
#  (7134000, 7136000),
#  (7170000, 7172000),
#  (7182000, 7184000),
#  (7188000, 7190000),
#  (7212000, 7214000),
#  (7252000, 7254000),
#  (7254000, 7256000),
#  (7268000, 7270000),
#  (7328000, 7330000),
#  (7358000, 7360000),
#  (7390000, 7392000),
#  (7422000, 7424000),
#  (7574000, 7576000),
#  (7594000, 7596000),
#  (7600000, 7602000),
#  (7724000, 7726000),
#  (7822000, 7824000),
#  (7914000, 7916000),
#  (7998000, 8000000)]

# %% [markdown]
# ### Plot kymographs of motifs

# %%
# kymograph: x-axis is position, y-axis is time
plt.scatter(location , unitSpikeTimes[0])

# %% [markdown]
# ### Poisson Surprise

# %%
mfr_ms = sum(spikeTrains[0])/len(spikeTrains[0]) # avg num of spikes per ms
isi_ms = np.diff(unitSpikeTimes_whole[0])
isi_ms_10 = [x for x in isi_ms if x <= 10]

poissonSim_ms = np.random.poisson(mfr_ms, (len(isi_ms),))
ks_2samp(isi_ms, poissonSim_ms)
# Out:
# KstestResult(statistic=0.9984006176924773, pvalue=0.0, statistic_location=0, statistic_sign=-1)

# %%
plt.figure(1)
plt.hist(isi_ms, bins = 100)
plt.xlabel("ISI (ms)")
plt.ylabel("# ISI in each bin")
plt.title("ISI Distribution for Unit 1")

plt.figure(2)
plt.hist(poissonSim)
plt.xlabel("Poisson Values")
plt.ylabel("# simulated values in each bin")
plt.title("Poisson Distribution (lambda = avg # spikes / sec)")
# Out:
# Text(0.5, 1.0, 'Poisson Distribution (lambda = avg # spikes / ms)')

# %%
max(unitSpikeTimes_whole[0])
# Out:
# 8114162

# %%
for i in range(3):
    mfr = sum(spikeTrains[i])/len(spikeTrains[i]) * 1000 # avg num of spikes per sec
    isi = np.diff(unitSpikeTimes_whole[i])
    
    poissonSim = np.random.poisson(mfr, (len(isi),))

    plt.figure(i) # gogobop
    plt.hist(isi, bins = 100)
    plt.xlabel("ISI (ms)")
    plt.ylabel("# ISI in each bin")
    plt.title(f"ISI Distribution for Unit {str(i+1)}, mfr={np.round(mfr,3)} spikes/sec")

# %%
for i in range(3):
    mfr = sum(spikeTrains[i])/len(spikeTrains[i]) * 1000 # avg num of spikes per sec
    isi = np.diff(unitSpikeTimes_whole[i])
    isi_restr = [x for x in isi if x <=10]
    
    poissonSim = np.random.poisson(mfr, (len(isi),))

    plt.figure(i)

    plt.subplot(1, 2, 1) # gogobop
    plt.hist(isi_restr, bins = 10)
    plt.xlabel("ISI (ms)")
    plt.ylabel("# ISI in each bin")
    plt.title(f"ISI Distribution for Unit {str(i+1)}")

    plt.subplot(1, 2, 2) # gogobop
    plt.hist(poissonSim, bins = 10)
    plt.xlabel("Poisson Values")
    plt.ylabel("# simulated values in each bin")
    plt.title(f"Poisson Distribution (lambda = {np.round(mfr,3)} spikes/sec)")
    plt.savefig(f"Unit {str(i+1)}.png")
